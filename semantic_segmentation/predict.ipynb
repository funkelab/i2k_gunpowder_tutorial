# %%
import gunpowder as gp
from funlib.learn.torch.models import UNet

import daisy
import zarr
import numpy as np
import torch

import logging

# %%
logging.basicConfig(level=logging.INFO)
# Constants
checkpoint = "test_checkpoint"
grow = (36, 36, 36)
voxel_size = gp.Coordinate((4, 4, 4))
input_shape = gp.Coordinate((76, 76, 76)) + grow
input_size = input_shape * voxel_size
output_shape = gp.Coordinate((36, 36, 36)) + grow
output_size = output_shape * voxel_size
context = (input_size - output_size) / 2

# %%
# initialize model
unet = UNet(
    in_channels=1,
    num_fmaps=16,
    fmap_inc_factor=5,
    downsample_factors=[(2, 2, 2), (2, 2, 2)],
    activation="ReLU",
    voxel_size=voxel_size,
    num_heads=1,
    constant_upsample=True,
)
logits = torch.nn.Conv3d(16, 4, (1,) * 3)
probs = torch.nn.Softmax()

semantic_model = torch.nn.Sequential(unet, logits, probs)
semantic_model.eval()
# Out:
# Sequential(
#   (0): UNet(
#     (l_conv): ModuleList(
#       (0): ConvPass(
#         (conv_pass): Sequential(
#           (0): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (1): ConvPass(
#         (conv_pass): Sequential(
#           (0): Conv3d(16, 80, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(80, 80, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (2): ConvPass(
#         (conv_pass): Sequential(
#           (0): Conv3d(80, 400, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(400, 400, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#     )
#     (l_down): ModuleList(
#       (0): Downsample(
#         (down): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): Downsample(
#         (down): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (r_up): ModuleList(
#       (0): ModuleList(
#         (0): Upsample(
#           (up): Upsample(scale_factor=(2.0, 2.0, 2.0), mode=nearest)
#         )
#         (1): Upsample(
#           (up): Upsample(scale_factor=(2.0, 2.0, 2.0), mode=nearest)
#         )
#       )
#     )
#     (r_conv): ModuleList(
#       (0): ModuleList(
#         (0): ConvPass(
#           (conv_pass): Sequential(
#             (0): Conv3d(96, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#         (1): ConvPass(
#           (conv_pass): Sequential(
#             (0): Conv3d(480, 80, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(80, 80, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (1): Conv3d(16, 4, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (2): Softmax(dim=None)
# )

# %%
raw = gp.ArrayKey("RAW")
predictions = gp.ArrayKey("PREDICTIONS")

reference_request = gp.BatchRequest()
reference_request.add(raw, input_size)
reference_request.add(predictions, output_size)

source = gp.ZarrSource(
    filename="../MB-Z1213-56.zarr",
    datasets={
        raw: "TEST/raw",
    },
)

# %%
with gp.build(source):
    total_input_roi = source.spec[raw].roi
total_output_roi = total_input_roi.grow(-context, -context)

daisy.prepare_ds(
    "predictions.zarr",
    "volumes/predictions",
    daisy.Roi(total_output_roi.get_offset(), total_output_roi.get_shape()),
    (4, 4, 4),
    np.float32,
    write_size=output_size,
    num_channels=4,
)
# Out:
# WARNING:gunpowder.nodes.hdf5like_source_base:WARNING: You didn't set 'interpolatable' for RAW (dataset TEST/raw). Based on the dtype uint8, it has been set to True. This might not be what you want.
# INFO:daisy.datasets:Reusing existing dataset

# %%
pipeline = (
    source
    + gp.Normalize(raw)
    + gp.Unsqueeze([raw])
    + gp.Unsqueeze([raw])
    + gp.torch.Predict(
        model=semantic_model,
        inputs={"input": raw},
        outputs={0: predictions},
        checkpoint=checkpoint,
    )
    + gp.Squeeze([raw, predictions])
    + gp.Squeeze([raw])
    + gp.ZarrWrite(
        output_dir="./",
        output_filename="predictions.zarr",
        dataset_names={
            raw: "volumes/raw",
            predictions: "volumes/predictions",
        },
        dataset_dtypes={predictions: gp.ArraySpec(roi=total_output_roi)},
    )
    + gp.Scan(reference_request, num_workers=3)
)

request = gp.BatchRequest()
request[raw] = gp.ArraySpec(roi=total_input_roi)
request[predictions] = gp.ArraySpec(roi=total_output_roi)

# %%
with gp.build(pipeline):
    pipeline.request_batch(request)
# Out:
# WARNING:gunpowder.nodes.hdf5like_source_base:WARNING: You didn't set 'interpolatable' for RAW (dataset TEST/raw). Based on the dtype uint8, it has been set to True. This might not be what you want.
# INFO:gunpowder.nodes.scan:scanning over 125 chunks
# INFO:gunpowder.torch.nodes.predict:Predicting on gpu
# INFO:gunpowder.torch.nodes.predict:Predicting on gpu
# INFO:gunpowder.torch.nodes.predict:Predicting on gpu
# /groups/mousebrainmicro/home/pattonw/anaconda3/envs/i2k/lib/python3.8/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# /groups/mousebrainmicro/home/pattonw/anaconda3/envs/i2k/lib/python3.8/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# /groups/mousebrainmicro/home/pattonw/anaconda3/envs/i2k/lib/python3.8/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# INFO:gunpowder.nodes.scan:allocating array of shape (400, 400, 400) for RAW
# INFO:gunpowder.nodes.scan:allocating array of shape (4, 360, 360, 360) for PREDICTIONS
# INFO:gunpowder.nodes.scan:processed chunk 1/125
# INFO:gunpowder.nodes.scan:processed chunk 2/125
# INFO:gunpowder.nodes.scan:processed chunk 3/125
# INFO:gunpowder.nodes.scan:processed chunk 4/125
# INFO:gunpowder.nodes.scan:processed chunk 5/125
# INFO:gunpowder.nodes.scan:processed chunk 6/125
# INFO:gunpowder.nodes.scan:processed chunk 7/125
# INFO:gunpowder.nodes.scan:processed chunk 8/125
# INFO:gunpowder.nodes.scan:processed chunk 9/125
# INFO:gunpowder.nodes.scan:processed chunk 10/125
# INFO:gunpowder.nodes.scan:processed chunk 11/125
# INFO:gunpowder.nodes.scan:processed chunk 12/125
# INFO:gunpowder.nodes.scan:processed chunk 13/125
# INFO:gunpowder.nodes.scan:processed chunk 14/125
# INFO:gunpowder.nodes.scan:processed chunk 15/125
# INFO:gunpowder.nodes.scan:processed chunk 16/125
# INFO:gunpowder.nodes.scan:processed chunk 17/125
# INFO:gunpowder.nodes.scan:processed chunk 18/125
# INFO:gunpowder.nodes.scan:processed chunk 19/125
# INFO:gunpowder.nodes.scan:processed chunk 20/125
# INFO:gunpowder.nodes.scan:processed chunk 21/125
# INFO:gunpowder.nodes.scan:processed chunk 22/125
# INFO:gunpowder.nodes.scan:processed chunk 23/125
# INFO:gunpowder.nodes.scan:processed chunk 24/125
# INFO:gunpowder.nodes.scan:processed chunk 83/125
# INFO:gunpowder.nodes.scan:processed chunk 84/125
# INFO:gunpowder.nodes.scan:processed chunk 85/125
# INFO:gunpowder.nodes.scan:processed chunk 86/125
# INFO:gunpowder.nodes.scan:processed chunk 87/125
# INFO:gunpowder.nodes.scan:processed chunk 88/125
# INFO:gunpowder.nodes.scan:processed chunk 89/125
# INFO:gunpowder.nodes.scan:processed chunk 90/125
# INFO:gunpowder.nodes.scan:processed chunk 91/125
# INFO:gunpowder.nodes.scan:processed chunk 92/125
# INFO:gunpowder.nodes.scan:processed chunk 93/125
# INFO:gunpowder.nodes.scan:processed chunk 94/125
# INFO:gunpowder.nodes.scan:processed chunk 95/125
# INFO:gunpowder.nodes.scan:processed chunk 96/125
# INFO:gunpowder.nodes.scan:processed chunk 97/125
# INFO:gunpowder.nodes.scan:processed chunk 98/125
# INFO:gunpowder.nodes.scan:processed chunk 99/125
# INFO:gunpowder.nodes.scan:processed chunk 100/125
# INFO:gunpowder.nodes.scan:processed chunk 101/125
# INFO:gunpowder.nodes.scan:processed chunk 102/125
# INFO:gunpowder.nodes.scan:processed chunk 103/125
# INFO:gunpowder.nodes.scan:processed chunk 104/125
# INFO:gunpowder.nodes.scan:processed chunk 105/125
# INFO:gunpowder.nodes.scan:processed chunk 106/125
# INFO:gunpowder.nodes.scan:processed chunk 107/125
# INFO:gunpowder.nodes.scan:processed chunk 108/125
# INFO:gunpowder.nodes.scan:processed chunk 109/125
# INFO:gunpowder.nodes.scan:processed chunk 110/125
# INFO:gunpowder.nodes.scan:processed chunk 111/125
# INFO:gunpowder.nodes.scan:processed chunk 112/125
# INFO:gunpowder.nodes.scan:processed chunk 113/125
# INFO:gunpowder.nodes.scan:processed chunk 114/125
# INFO:gunpowder.nodes.scan:processed chunk 115/125
# INFO:gunpowder.nodes.scan:processed chunk 116/125
# INFO:gunpowder.nodes.scan:processed chunk 117/125
# INFO:gunpowder.nodes.scan:processed chunk 118/125
# INFO:gunpowder.nodes.scan:processed chunk 119/125
# INFO:gunpowder.nodes.scan:processed chunk 120/125
# INFO:gunpowder.nodes.scan:processed chunk 121/125
# INFO:gunpowder.nodes.scan:processed chunk 122/125
# INFO:gunpowder.nodes.scan:processed chunk 123/125
# INFO:gunpowder.nodes.scan:processed chunk 124/125
# INFO:gunpowder.nodes.scan:processed chunk 125/125
# INFO:gunpowder.producer_pool:terminating workers...
# INFO:gunpowder.producer_pool:joining workers...
# INFO:gunpowder.producer_pool:done

# %%
# Post processing
results_zarr = zarr.open(f"predictions.zarr", "r+")
results = results_zarr["volumes/predictions"]

semantic_segmentation = np.argmax(results, axis=0)

results_zarr["semantic_segmentation"] = semantic_segmentation
results_zarr["semantic_segmentation"].attrs["offset"] = total_output_roi.get_offset()
results_zarr["semantic_segmentation"].attrs["resolution"] = voxel_size
# Out:
# WARNING:gunpowder.nodes.hdf5like_source_base:WARNING: You didn't set 'interpolatable' for RAW (dataset TEST/raw). Based on the dtype uint8, it has been set to True. This might not be what you want.
# INFO:gunpowder.producer_pool:terminating workers...
# INFO:gunpowder.producer_pool:joining workers...
# INFO:gunpowder.producer_pool:done
